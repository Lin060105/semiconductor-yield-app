# %%
print("Hello, Jupyter!")
# Out:
# Hello, Jupyter!

# %%
import pandas as pd
from pycaret.classification import *
import matplotlib.pyplot as plt  # 用來保存圖片，如果 PyCaret 不自動

# 載入資料（假設 secom_processed.csv 在根目錄）
dataset = pd.read_csv('secom_processed.csv')
print(dataset.head())  # 檢查資料載入正確，label 欄位應存在
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 from pycaret.classification import *
#       3 import matplotlib.pyplot as plt  # 用來保存圖片，如果 PyCaret 不自動
#       5 # 載入資料（假設 secom_processed.csv 在根目錄）
#
# ModuleNotFoundError: No module named 'pycaret'
